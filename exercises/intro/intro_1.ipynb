# %%
import pandas as pd

# %%
import requests
from PIL import Image

# %%
Image.open(requests.get('https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/cute-cat-photos-1593441022.jpg?crop=0.669xw:1.00xh;0.166xw,0&resize=640:*', stream=True).raw)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x638>

# %%
# !ls ../merge_xls/output/Combined_Payers_with_IDs.csv
# Out:
# ../merge_xls/output/Combined_Payers_with_IDs.csv

# %%
print(pd.read_csv('../merge_xls/output/Combined_Payers_with_IDs.csv'))
# Out:
#                                    Payer Name Payer ID Availity Payer ID  \
# 0                  1199 NATIONAL BENEFIT FUND    13162             13162
# 1     AARP UNITEDHEALTHCARE INSURANCE COMPANY    36273             36273
# 2                         ABSOLUTE TOTAL CARE    68069             68069
# 3                         ABSOLUTE TOTAL CARE        -                 -
# 4                        ACS BENEFIT SERVICES    11009             11009
# ...                                       ...      ...               ...
# 4312                                      NaN      NaN               NaN
# 4313                                      NaN      NaN               NaN
# 4314                                      NaN      NaN               NaN
# 4315          First Managed Care Options Inc.    40270               NaN
# 4316          First Managed Care Options Inc.    40270               NaN
#
#      Change HC Payer ID
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 4312                NaN
# 4313                NaN
# 4314                NaN
# 4315              40270
# 4316              40270
#
# [4317 rows x 4 columns]

# %%
# I AM NOT DONE

# %%
def double_array(a):
    raise Exception('lol')
    return [x * 2 for x in a]
